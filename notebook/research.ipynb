# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('BX-Books.csv', sep = ';', on_bad_lines = 'skip', encoding='latin-1', low_memory = False)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.tail()
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.iloc[1]['Image-URL-L'] # retrieves the second row large image of the data - here CLARA CALLAN
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg'

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-L']]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.rename(columns={"Book-Title":"Title",
                      "Book-Author":"Author",
                      "Year-Of-Publication":"Year",
                      "Image-URL-L":"Image_url"}, inplace = True) # to commit these name changes permanently

# %%
books.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  Year                   Publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            Image_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv('BX-Users.csv', sep = ';', on_bad_lines = 'skip', encoding = 'latin-1', low_memory = False)

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.tail()
# Out:
#         User-ID                            Location   Age
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
users.rename(columns = {"User-ID":'User_id'}, inplace = True)

# %%
users.head()
# Out:
#    User_id                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings = pd.read_csv('BX-Book-Ratings.csv', sep = ';', on_bad_lines = 'skip', encoding = 'latin-1', low_memory = False)

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings.rename(columns = {"User-ID":'User_id',
               "Book-Rating":'Rating'}, inplace = True)

# %%
ratings.head()
# Out:
#    User_id        ISBN  Rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
print(books.shape, users.shape, ratings.shape, sep='\n')
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
# users reading multiple books
ratings['User_id'].value_counts()
# Out:
# User_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 119573        1
# 276706        1
# 276697        1
# 276679        1
# 276676        1
# Name: count, Length: 105283, dtype: int64

# %%
# Store Users who had atleast rated more than 200 books
x = ratings['User_id'].value_counts() > 200

# %%
x
# Out:
# User_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 119573    False
# 276706    False
# 276697    False
# 276679    False
# 276676    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape # Total users = 278858 , Users who rated > 200 books = 899
# Out:
# (899,)

# %%
y = x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        116122,  44296,  28634,  59727,  73681, 274808, 188951,   9856, 155916,
#        268622],
#       dtype='int64', name='User_id', length=899)

# %%
# Merging Books_data with ratings
ratings_with_booksData = ratings.merge(books, on='ISBN')

# %%
ratings_with_booksData.head()
# Out:
#    User_id        ISBN  Rating  \
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6
#
#                                                Title           Author  Year  \
# 0                               Flesh Tones: A Novel       M. J. Rose  2002
# 1                                   Rites of Passage       Judith Rae  2001
# 2                                       The Notebook  Nicholas Sparks  1996
# 3                                     Help!: Level 1    Philip Prowse  1999
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather  2001
#
#                     Publisher  \
# 0            Ballantine Books
# 1                      Heinle
# 2                Warner Books
# 3  Cambridge University Press
# 4  Cambridge University Press
#
#                                            Image_url
# 0  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
# which book has got how many number of ratings
number_of_ratings = ratings_with_booksData.groupby('Title')['Rating'].count().reset_index()

# %%
number_of_ratings.head()
# Out:
#                                                Title  Rating
# 0   A Light in the Storm: The Civil War Diary of ...       4
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4   Beyond IBM: Leadership Marketing and Finance ...       1

# %%
number_of_ratings.rename(columns = {"Rating":'number_of_ratings'}, inplace = True)

# %%
number_of_ratings.head()
# Out:
#                                                Title  number_of_ratings
# 0   A Light in the Storm: The Civil War Diary of ...                  4
# 1                              Always Have Popsicles                  1
# 2               Apple Magic (The Collector's series)                  1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                  1
# 4   Beyond IBM: Leadership Marketing and Finance ...                  1

# %%
final_rating = ratings_with_booksData.merge(number_of_ratings, on = 'Title')

# %%
final_rating.head()
# Out:
#    User_id        ISBN  Rating  \
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6
#
#                                                Title           Author  Year  \
# 0                               Flesh Tones: A Novel       M. J. Rose  2002
# 1                                   Rites of Passage       Judith Rae  2001
# 2                                       The Notebook  Nicholas Sparks  1996
# 3                                     Help!: Level 1    Philip Prowse  1999
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather  2001
#
#                     Publisher  \
# 0            Ballantine Books
# 1                      Heinle
# 2                Warner Books
# 3  Cambridge University Press
# 4  Cambridge University Press
#
#                                            Image_url  number_of_ratings
# ...

# %%
# Filtering books having more than 50 ratings
final_rating = final_rating[final_rating['number_of_ratings'] >= 50]

# %%
final_rating.head()
# Out:
#    User_id        ISBN  Rating                 Title           Author  Year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel       M. J. Rose  2002
# 2   276727  0446520802       0          The Notebook  Nicholas Sparks  1996
# 6   276744  038550120X       7       A Painted House     JOHN GRISHAM  2001
# 7   276746  0425115801       0             Lightning   Dean R. Koontz  1996
# 8   276746  0449006522       0   Manhattan Hunt Club        JOHN SAUL  2002
#
#                   Publisher  \
# 0          Ballantine Books
# 2              Warner Books
# 6                 Doubleday
# 7  Berkley Publishing Group
# 8          Ballantine Books
#
#                                            Image_url  number_of_ratings
# 0  http://images.amazon.com/images/P/034545104X.0...                 60
# 2  http://images.amazon.com/images/P/0446520802.0...                650
# 6  http://images.amazon.com/images/P/038550120X.0...                838
# ...

# %%
# Drop duplicates
final_rating.drop_duplicates(['User_id','Title'], inplace = True) # if two or more rows have the same values in both the 'User_id' and 'Title' columns, only the first occurrence is kept and the duplicates are removed

# %%
final_rating.head()
# Out:
#    User_id        ISBN  Rating                 Title           Author  Year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel       M. J. Rose  2002
# 2   276727  0446520802       0          The Notebook  Nicholas Sparks  1996
# 6   276744  038550120X       7       A Painted House     JOHN GRISHAM  2001
# 7   276746  0425115801       0             Lightning   Dean R. Koontz  1996
# 8   276746  0449006522       0   Manhattan Hunt Club        JOHN SAUL  2002
#
#                   Publisher  \
# 0          Ballantine Books
# 2              Warner Books
# 6                 Doubleday
# 7  Berkley Publishing Group
# 8          Ballantine Books
#
#                                            Image_url  number_of_ratings
# 0  http://images.amazon.com/images/P/034545104X.0...                 60
# 2  http://images.amazon.com/images/P/0446520802.0...                650
# 6  http://images.amazon.com/images/P/038550120X.0...                838
# ...

# %%
final_rating.isnull().sum()
# Out:
# User_id              0
# ISBN                 0
# Rating               0
# Title                0
# Author               0
# Year                 0
# Publisher            0
# Image_url            0
# number_of_ratings    0
# dtype: int64

# %%
# For Collaborative Filtering, we have to convert this data into a Pivot Table 
# Ratings - root point here for the Collaborative-based Recommender System 
book_pivot = final_rating.pivot_table(columns='User_id', index='Title', values='Rating')

# %%
book_pivot
# Out:
# User_id                                             8       9       14      \
# Title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# ...

# %%
book_pivot.isnull().sum()
# Out:
# User_id
# 8         2442
# 9         2442
# 14        2443
# 16        2442
# 17        2441
#           ...
# 278843    2420
# 278844    2443
# 278846    2443
# 278851    2442
# 278854    2440
# Length: 47994, dtype: int64

# %%
book_pivot.shape
# Out:
# (2444, 47994)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# User_id                                             8       9       14      \
# Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
# Converting the Pivot Table into a CSR matrix before training it
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 113483 stored elements and shape (2444, 47994)>

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
# Importing the Nearest-Neighbour Model
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm = 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot
# Out:
# User_id                                             8       9       14      \
# Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
book_pivot.iloc[237,:] # selects the book info of the row index 237 which is the 238th row
# Out:
# User_id
# 8         0.0
# 9         6.0
# 14        0.0
# 16        0.0
# 17        0.0
#          ...
# 278843    0.0
# 278844    0.0
# 278846    0.0
# 278851    0.0
# 278854    0.0
# Name: Beloved (Plume Contemporary Fiction), Length: 47994, dtype: float64

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6) # suggestion - need 6 nearest books with respect to the given input book
# reshape(1,-1) - reshape into 1 row & unknown number of columns

# %%
distance # 0 indicates that the distance is calculated with the book_name by itself
# Out:
# array([[ 0.        , 74.13501197, 74.14849965, 74.25631286, 74.38413809,
#         74.42445835]])

# %%
suggestion
# Out:
# array([[ 237, 1713,  770,   65, 1391,  284]])

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Beloved (Plume Contemporary Fiction)', 'The Blooding',
#        'Ground Zero and Beyond', 'A Secret Affair', 'Reasonable Doubt',
#        'Blood and Gold (Rice, Anne, Vampire Chronicles.)'],
#       dtype='object', name='Title')

# %%
# Keep Book Names in a variable
book_names = book_pivot.index

# %%
book_names
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='Title', length=2444)

# %%
book_names[1]
# Out:
# '16 Lighthouse Road'

# %%
final_rating.head()
# Out:
#    User_id        ISBN  Rating                 Title           Author  Year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel       M. J. Rose  2002
# 2   276727  0446520802       0          The Notebook  Nicholas Sparks  1996
# 6   276744  038550120X       7       A Painted House     JOHN GRISHAM  2001
# 7   276746  0425115801       0             Lightning   Dean R. Koontz  1996
# 8   276746  0449006522       0   Manhattan Hunt Club        JOHN SAUL  2002
#
#                   Publisher  \
# 0          Ballantine Books
# 2              Warner Books
# 6                 Doubleday
# 7  Berkley Publishing Group
# 8          Ballantine Books
#
#                                            Image_url  number_of_ratings
# 0  http://images.amazon.com/images/P/034545104X.0...                 60
# 2  http://images.amazon.com/images/P/0446520802.0...                650
# 6  http://images.amazon.com/images/P/038550120X.0...                838
# ...

# %%
np.where(book_pivot.index == '10 Lb. Penalty')[0][0] # gives index 0 as '10 Lb.Penalty' is specified which is the Book Name in row 1
# np.where() returns a tuple, not a number.
# (array([237]),) - A tuple where the first element is an array
# array([237]) - An array of matching indices
# first [0] picks the first element from this array
# If multiple matches exist, [0][0] ensures we grab only the first match
# Out:
# np.int64(0)

# %%
# final_rating['Title'].value_counts()
Ids = np.where(final_rating['Title'] == 'A Secret Affair')[0][0]

# %%
final_rating.iloc[Ids]['Image_url']
# Out:
# 'http://images.amazon.com/images/P/0061012289.01.LZZZZZZZ.jpg'

# %%
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name
# Out:
# [Index(['Beloved (Plume Contemporary Fiction)', 'The Blooding',
#         'Ground Zero and Beyond', 'A Secret Affair', 'Reasonable Doubt',
#         'Blood and Gold (Rice, Anne, Vampire Chronicles.)'],
#        dtype='object', name='Title')]

# %%
Ids_index =[]
for name in book_name[0]:
    Ids = np.where(final_rating['Title'] == name)[0][0]
    Ids_index.append(Ids)

# %%
Ids_index
# Out:
# [np.int64(620),
#  np.int64(5045),
#  np.int64(13605),
#  np.int64(2774),
#  np.int64(1412),
#  np.int64(7971)]

# %%
for ids in Ids_index:
    url = final_rating.iloc[ids]['Image_url']
    print(url)
# Out:
# http://images.amazon.com/images/P/0452264464.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0553282816.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/1401088945.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0061012289.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0804107491.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0345409329.01.LZZZZZZZ.jpg

# %%
# import gzip

# %%
# Save the binary objects
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_names, open('artifacts/book_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
# pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
'''import zipfile

zip_file = "artifacts/book_pivot.zip"
pkl_file = "artifacts/book_pivot.pkl"

# Save pickle file first
with open(pkl_file, 'wb') as f_out:
    pickle.dump(book_pivot, f_out, protocol=pickle.HIGHEST_PROTOCOL)

# Compress the pickle file into a ZIP archive
with zipfile.ZipFile(zip_file, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(pkl_file, arcname=pkl_file)

print(f"Compressed and saved to '{zip_file}')'''
# Out:
# 'import zipfile\n\nzip_file = "artifacts/book_pivot.zip"\npkl_file = "artifacts/book_pivot.pkl"\n\n# Save pickle file first\nwith open(pkl_file, \'wb\') as f_out:\n    pickle.dump(book_pivot, f_out, protocol=pickle.HIGHEST_PROTOCOL)\n\n# Compress the pickle file into a ZIP archive\nwith zipfile.ZipFile(zip_file, \'w\', zipfile.ZIP_DEFLATED) as zipf:\n    zipf.write(pkl_file, arcname=pkl_file)\n\nprint(f"Compressed and saved to \'{zip_file}\')'

# %%
import zipfile

zip_file = "artifacts/book_pivot.zip"
pkl_filename = "book_pivot.pkl"  # Internal archive name

# Compress and dump pickle directly into ZIP
with zipfile.ZipFile(zip_file, 'w', zipfile.ZIP_DEFLATED) as zipf:
    with zipf.open(pkl_filename, 'w') as f_out:  # Writing directly into ZIP
        pickle.dump(book_pivot, f_out, protocol=pickle.HIGHEST_PROTOCOL)

print(f"Compressed and saved directly to '{zip_file}'")
# Out:
# Compressed and saved directly to 'artifacts/book_pivot.zip'

# %%
# (gzip.open('book_pivot.pkl.gz', 'wb').write(open('book_pivot.pkl', 'rb').read()))

# %% [markdown]
# # Model Testing

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6)

    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            if j == book_name:
                print(f"You searched {book_name}\n")
                print("The suggested books are:\n")
            else:
                print(j)

# %%
book_name = 'Lightning'
recommend_book(book_name)
# Out:
# You searched Lightning
#
# The suggested books are:
#
# Star
# Now and Forever
# Morning, Noon &amp; Night
# Special Delivery: A Novel
# Night Chills
